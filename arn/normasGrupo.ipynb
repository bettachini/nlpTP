# %% [markdown]
# # Clanificación de normas

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import csv file with column names
dataFileName = 'clasificaciónNormas.csv' 
df = pd.read_csv(dataFileName, names=['Normas', 'Objetivo'])

# %%
# strip entries at column Normas of last four characters
df['Normas'] = df['Normas'].str[:-4]
df
# Out:
#        Normas                   Objetivo
# 0    0-0-1_r2      Instalaciones clase 1
# 1   0-11-1_r3      Instalaciones clase 1
# 2   0-11-2_r2    Autorización específica
# 3   0-11-3_r1  Entrenamiento de personal
# 4   0-11-4_r0             Licenciamiento
# ..        ...                        ...
# 59  8-11-3_r0         Permiso individual
# 60   8-2-1_r0                  Seguridad
# 61   8-2-2_r1                  Seguridad
# 62   8-2-3_r3                  Seguridad
# 63   8-2-4_r1                  Seguridad
#
# [64 rows x 2 columns]

# %%
# same as above but with yrange up to 30 
df['Objetivo'].value_counts(normalize=True).mul(100).plot(kind='bar', ylabel='Proporción [%]')
plt.ylim(0, 35)
for i, v in enumerate(df['Objetivo'].value_counts(normalize=True).mul(100)):
    plt.text(i, v + 1, f'{v:.2f}', ha='center', va='bottom', rotation=90)
# title
plt.title('Clasificación de Normas ARN')
# Out:
# Text(0.5, 1.0, 'Clasificación de Normas ARN')
